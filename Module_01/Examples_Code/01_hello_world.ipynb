# %% [markdown]
# # Purpose: To understand the print function

# %%
print("Hello Welcome to the Python Programming")
print("Mai ek Python Student hoon")
# Out:
# Hello Welcome to the Python Programming
# Mai ek Python Student hoon

# %% [markdown]
# ## Basic Math inside print

# %%
print("5 + 5 is equal to : ",5 + 5)
# Out:
# 5 + 5 is equal to :  10
