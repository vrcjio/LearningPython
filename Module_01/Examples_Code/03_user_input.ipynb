# %% [markdown]
# # Purpose: Learning how to take input from user

# %%
user_name = input("Enter you'r name: ")
print("Welcome: ",user_name,"| Your enjoye pyton?")
# Out:
# Enter you'r name:  vishnu
# Welcome:  vishnu | Your enjoye pyton?

# %% [markdown]
# ## 🧮Simple Calculator input

# %%
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))
print("Addition is: ",num1 + num2)
# Out:
# Enter first number:  2
# Enter second number:  3
# Addition is:  5
