# %%
from sklearn.datasets import load_iris
iris_raw = load_iris()
print(iris_raw.keys())
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])

# %%
import pandas as pd

df = pd.DataFrame(
    data = iris_raw.data,
    columns = iris_raw.feature_names
)
df['Species_Name'] = [iris_raw.target_names[i] for i in iris_raw.target] 
df['Target_Code'] = iris_raw.target
print(df.head(5))
print(df.tail(5))
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   Species_Name  Target_Code
# 0       setosa            0
# 1       setosa            0
# 2       setosa            0
# 3       setosa            0
# 4       setosa            0
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# ...

# %%
import numpy as np
X = df[iris_raw.feature_names].to_numpy()
y = df['Target_Code'].to_numpy()

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test  = train_test_split(X, y, train_size=0.8, random_state=42)

print(X_train.shape,"  ", X_test.shape)
print(y_train.shape,"  ", y_test.shape)
print(y_test)
print(y_train)
# Out:
# (120, 4)    (30, 4)
# (120,)    (30,)
# [1 0 2 1 1 0 1 2 1 1 2 0 0 0 0 1 2 1 1 2 0 2 0 2 2 2 2 2 0 0]
# [0 0 1 0 0 2 1 0 0 0 2 1 1 0 0 1 2 2 1 2 1 2 1 0 2 1 0 0 0 1 2 0 0 0 1 0 1
#  2 0 1 2 0 2 2 1 1 2 1 0 1 2 0 0 1 1 0 2 0 0 1 1 2 1 2 2 1 0 0 2 2 0 0 0 1
#  2 0 2 2 0 1 1 2 1 2 0 2 1 2 1 1 1 0 1 1 0 1 2 2 0 1 2 2 0 2 0 1 2 2 1 2 1
#  1 2 2 0 1 2 0 1 2]

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble  import RandomForestClassifier
from sklearn.metrics import accuracy_score

dt = DecisionTreeClassifier(max_depth=3,random_state=42)
dt.fit(X_train, y_train)
print("DecisionTreeClassifier Accuracy: ",accuracy_score(y_test,dt.predict(X_test)))

lr = LogisticRegression(max_iter=200)
lr.fit(X_train,y_train)
print("LogisticRegression Accuracy: ",accuracy_score(y_test,lr.predict(X_test)))

kn = KNeighborsClassifier(n_neighbors=3)
kn.fit(X_train, y_train)
print("KNeighborsClassifier Accuray: ",accuracy_score(y_test,kn.predict(X_test)))

rf = RandomForestClassifier(random_state=42)
rf.fit(X_train, y_train)
print("RandomForestClassifier Accuracy: ",accuracy_score(y_test,rf.predict(X_test)))
# Out:
# DecisionTreeClassifier Accuracy:  1.0
# LogisticRegression Accuracy:  1.0
# KNeighborsClassifier Accuray:  1.0
# RandomForestClassifier Accuracy:  1.0
